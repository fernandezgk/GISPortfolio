# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('county_election_data_2000-2016.csv')
df.head()
# Out:
#    FIPS  gop_2000_votes  dem_2000_votes  totalvotes_2000  gop_2000_prc  \
# 0  1001         11993.0          4942.0          17208.0         69.69
# 1  1003         40872.0         13997.0          56480.0         72.37
# 2  1005          5096.0          5188.0          10395.0         49.02
# 3  1007          4273.0          2710.0           7101.0         60.17
# 4  1009         12667.0          4977.0          17973.0         70.48
#
#    dem_2000_prc  gop_minus_dem_prc_2000  gop_2004_votes  dem_2004_votes  \
# 0         28.72                   40.97         15196.0          4758.0
# 1         24.78                   47.59         52971.0         15599.0
# 2         49.91                   -0.89          5899.0          4832.0
# 3         38.16                   22.01          5472.0          2089.0
# 4         27.69                   42.79         17386.0          3938.0
#
#    totalvotes_2004  ...  totalvotes_2012  gop_2012_prc  dem_2012_prc  \
# ...

# %%
a = abs(df.gop_minus_dem_prc_2008)
b = abs(df.gop_minus_dem_prc_2012)
c = abs(df.gop_minus_dem_prc_2016)

a2 = np.sum(a>=20) #2008landslide
b2 = np.sum(b>=20) #2012landslide
c2 = np.sum(c>=20) #20162landslide

leng = len(df.FIPS)

a3 = (a2/leng)*100
b3 = (b2/leng)*100
c3 = (c2/leng)*100
print()

d = np.sum(a<=10) #2008Competitive
e = np.sum(b<=10) #2012Competitive
f = np.sum(c<=10) #2016Competitive
print()

d2 = (d/leng)*100
e2 = (e/leng)*100
f2 = (f/leng)*100
print()

plt.plot([a3,b3,c3], label = 'Landslide Counties', color = 'orange')
plt.plot([d2,e2,f2], label = 'Competitive Counties', color = 'maroon')
plt.xlabel('Year')
plt.ylabel('County Percentage')
plt.title('Presidential Election Landslide & Competative Counties')
plt.xticks(np.arange(3), ['2008','2012','2016'])
plt.legend()
plt.savefig('lsncc.png', dpi = 300)
